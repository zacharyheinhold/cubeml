# %% [markdown]
# # Install labelstudio

# %% [markdown]
# # Install in base

# %% [markdown]
# `sudo apt install libpq-dev python3-dev`

# %%
#pip install --upgrade label-studio
# Out:
# : 1

# %%
label-studio start
# Out:
# => Database and media directory: /home/gmobot/.local/share/label-studio
# Read environment variables from: /home/gmobot/.local/share/label-studio/.env
# get 'SECRET_KEY' casted as '<class 'str'>' with default ''
# => Static URL is set to: /static/
# => Database and media directory: /home/gmobot/.local/share/label-studio
# Read environment variables from: /home/gmobot/.local/share/label-studio/.env
# get 'SECRET_KEY' casted as '<class 'str'>' with default ''
# => Static URL is set to: /static/
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /pypi/label-studio/json HTTP/1.1" 200 32786
#
#    ╔═════════════════════════════════════╗
#    ║                                     ║
#    ║   Update available 1.8.2 → 1.13.1   ║
#    ║   Run pip install -U label-studio   ║
#    ║                                     ║
#    ╚═════════════════════════════════════╝
#
# Can't read version file: ls-version_.py. Fall back to: version_.py
# ...

# %% [markdown]
# ## Install in a conda env
